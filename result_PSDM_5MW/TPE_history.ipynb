# %% [markdown]
# ![multi_scenario_optimization_history.png](attachment:multi_scenario_optimization_history.png)

# %% [markdown]
# ![refined_multi_scenario_academic_feature_importance.png](attachment:refined_multi_scenario_academic_feature_importance.png)
