# %% [markdown]
# ![mae_comparison_10mw_fragility.png](attachment:mae_comparison_10mw_fragility.png) ![mae_comparison_10mw_response.png](attachment:mae_comparison_10mw_response.png) ![mae_comparison_5mw_fragility.png](attachment:mae_comparison_5mw_fragility.png) ![mae_comparison_5mw_response.png](attachment:mae_comparison_5mw_response.png)
